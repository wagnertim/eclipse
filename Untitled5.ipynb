# %%
import netCDF4
import matplotlib.pyplot as plt
import numpy as np

# %%
f1 = '/Users/timw/data/halo/chiwaukee_doppler_lidar_stare_20230802.cdf'
f2 = '/Users/timw/data/halo/chiwaukee_doppler_lidar_stare_20230803.cdf'

ds1 = netCDF4.Dataset(f1)

class dl1:

    time = ds1['times'][:]
    height = ds1['height'][:]
    w = ds1['w'][:]
    snr = ds1['intensity'][:]


ds2 = netCDF4.Dataset(f2)

class dl2:

    time = ds2['times'][:]
    height = ds2['height'][:]
    w = ds2['w'][:]
    snr = ds2['intensity'][:]

# %%
plt.figure()
plt.pcolormesh(dl1.time, dl1.height, dl1.w)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 plt.figure()
# ----> 2 plt.pcolormesh(dl1.time, dl1.height, dl1.w)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/pyplot.py:3731, in pcolormesh(alpha, norm, cmap, vmin, vmax, colorizer, shading, antialiased, data, *args, **kwargs)
#    3717 @_copy_docstring_and_deprecators(Axes.pcolormesh)
#    3718 def pcolormesh(
#    3719     *args: ArrayLike,
#    (...)
#    3729     **kwargs,
#    3730 ) -> QuadMesh:
# -> 3731     __ret = gca().pcolormesh(
#    3732         *args,
#    3733         alpha=alpha,
#    3734         norm=norm,
#    3735         cmap=cmap,
#    3736         vmin=vmin,
#    3737         vmax=vmax,
#    3738         colorizer=colorizer,
#    3739         shading=shading,
#    3740         antialiased=antialiased,
# ...

# %%
print(dl1.time)
# Out:
# [1.6927781e-02 2.2577779e-02 2.8224999e-02 ... 2.3990065e+01 2.3995710e+01
#  2.4001362e+01]
