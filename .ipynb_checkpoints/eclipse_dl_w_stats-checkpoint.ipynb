# %% [markdown]
# # Eclipse doppler lidar stats
#
# This notebook calculates the vertical velocity stats associated with the eclipse. In this program, we're going to take a 30 min running average and find the variance associated with that.

# %% [markdown]
# ## Preliminary matters
#
# Load the relevant modules.

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import netCDF4
from scipy import interpolate as interp

# %% [markdown]
# Define a couple of functions: one to read the DL files, and one to find the indext of the nearest value.

# %%
def readDL(f):
    
    ds = netCDF4.Dataset(f)
    
    class out:
        
        unixTime = ds['base_time'][:] + ds['time_offset'][:]
        time = ds['time'][:]/3600 # Hours UTC 
        height = ds['range'][:]
        w = ds['radial_velocity'][:]
        qc_w = ds['qc_radial_velocity'][:]
        intensity = ds['intensity'][:]
        back = ds['attenuated_backscatter'][:]
        
        
    out.w[np.where(out.qc_w != 0)] = np.nan
    
    return out

def findNearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return idx

# %% [markdown]
# ## Data collection
#
# The SGP vertical velocity observations are in hourly files. We want to join all of the data together into a uniform structure.

# %%
iter = 0
    
for file in sorted(glob.iglob('/data/eclipse/dlfpt/*.cdf')):
    
    dli = readDL(file)
    
    if iter ==0:
        
        class dl:
    
            unixTime = np.array(dli.unixTime)
            time =  np.array(dli.time)
            height =  np.array(dli.height)
            w =  np.array(dli.w)
            intensity = np.array(dli.intensity)
            back = np.array(dli.back)

    
    else:
        
        dl.unixTime = np.concatenate((dl.unixTime, dli.unixTime))
        dl.time = np.concatenate((dl.time, dli.time))
        dl.w = np.concatenate((dl.w, dli.w))
        dl.intensity = np.concatenate((dl.intensity, dli.intensity))
        dl.back = np.concatenate((dl.back, dli.back))

    iter = iter+1
    
#dl.time = dl.time - (18+47/60) #  convert to eclipse-relative time

# %% [markdown]
# ## Statistical analysis
#
# To obtain the vertical veolicty variance, we need to first come up with a running average.
#
# First we'll need to interpolate the data to a constant 1 s grid.

# %%
timeNew = np.linspace(0,24,86400)
interpFunc = interp.RectBivariateSpline(dl.time, dl.height, dl.w,kx=1, ky=1)

wNew = interpFunc(timeNew, dl.height)
wPrime = 0 *wNew # quick and direty way to zero out a matrix with same dimensions as wNew

# %%
totalStartIdx = findNearest(timeNew, 15/60)
totalEndIdx = findNearest(timeNew, 24 - 15/60)

for i in range(totalStartIdx, totalEndIdx):
    
    meanW = np.mean(wNew[i-900:i+900,:],axis=0)
    wPrime[i,:] = wNew[i,:]-meanW
    
    
plt.figure(figsize=(10, 3), dpi=300)
plt.pcolormesh(timeNew-(18+47/60), dl.height, np.transpose(wPrime),cmap = 'seismic')
plt.colorbar()
plt.clim([-3, 3])
plt.ylim([0,2000])
plt.xlim([-3,3])
plt.show()

plt.figure(figsize=(10, 3), dpi=300)
plt.pcolormesh((dl.time)-(18+47/60), dl.height, np.transpose(dl.w),cmap = 'seismic')
plt.colorbar()
plt.clim([-3, 3])
plt.ylim([0,2000])
plt.xlim([-3,3])
plt.show()

plt.figure(figsize=(10, 3), dpi=300)
plt.pcolormesh(timeNew-(18+47/60), dl.height, np.transpose(wNew),cmap = 'seismic')
plt.colorbar()
plt.clim([-3, 3])
plt.ylim([0,2000])
plt.xlim([-3,3])
plt.show()
